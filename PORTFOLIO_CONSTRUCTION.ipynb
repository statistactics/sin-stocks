# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Storing Names of Sin and Non-Sin Stocks in Variables

# %%
non_sin_df = pd.read_excel("Monthly Return_Coffee Products.xlsx", parse_dates = True)
sin_df = pd.read_excel("Monthly Return_Alcoholic Products.xlsx", parse_dates = True)

# %%
sin_df.head()
# Out:
#    PERMNO Names Date  Standard Industrial Classification Code Ticker Symbol  \
# 0   10225 2011-10-31                                     2082          BEAM
# 1   10225 2011-11-30                                     2082          BEAM
# 2   10225 2011-12-30                                     2082          BEAM
# 3   10225 2012-01-31                                     2082          BEAM
# 4   10225 2012-02-29                                     2082          BEAM
#
#   Company Name  Price or Bid/Ask Average
# 0     BEAM INC                 49.430000
# 1     BEAM INC                 52.520000
# 2     BEAM INC                 51.230000
# 3     BEAM INC                 52.310001
# 4     BEAM INC                 55.080002

# %%
sin_list = sin_df["Ticker Symbol"].unique()
sin_list
# Out:
# array(['BEAM', 'BEER', 'PFB', 'ABW', 'GBL', 'RUP', 'CNB', 'CKB', 'FAL',
#        'FALB', 'DRE', 'NBW', 'GENBB', 'RG', 'RGLD', 'SLZ', 'SFR', 'KNBWY',
#        'GRRR', nan, 'LONE', 'GHB', 'ABUD', 'BUD', 'ACCOB', 'RKY', 'TAP',
#        'PABT', 'OLYB', 'PTBC', 'HAN', 'BAS', 'SXC', 'CU', 'CCU', 'THT',
#        'HOOK', 'BREW', 'SAM', 'CFN', 'IBCO', 'BRH', 'ABV', 'ABEV', 'AED',
#        'MLB', 'LQU', 'ROX', 'CREG', 'BORN', 'FO', 'MWGP', 'MGPI', 'AFTI',
#        'DR', 'CUE', 'BACA', 'BBRL', 'ADC', 'SH', 'DCS', 'VO', 'HIR',
#        'CHLN', 'CGAS', 'BJD', 'BFD', 'BF', 'CDL', 'DIL', 'GDS', 'SBR',
#        'HBL', 'TFZ', 'TFI', 'HTC', 'JACQ', 'BBR', 'CNWN', 'CDG', 'CDB',
#        'STZ', 'RAIN', 'TBVT', 'TYLR', 'THTR', 'DEO', 'RUM', 'VCO', 'ADSO',
#        'NDC', 'GWT', 'CEDC', 'PTT'], dtype=object)

# %%
non_sin_list = non_sin_df["Ticker Symbol"].unique()
non_sin_list
# Out:
# array(['FARM', 'GMCR', 'PEET', 'JVA'], dtype=object)

# %% [markdown]
# # Reading in Files

# %%
stocks_df = pd.read_csv("final_merged.csv", parse_dates = ["Unnamed: 0"])
stocks_df.set_index("Unnamed: 0", inplace=True)
stocks_df.index.name = "Date"
stocks_df.head()
# Out:
#             ABEV  ABUD  ABV  ABW  ACCOB     ADC  ADSO  AED  AFTI  BACA  ...  \
# Date                                                                    ...
# 1962-07-31   NaN   NaN  NaN  NaN    NaN  37.000   NaN  NaN   NaN   NaN  ...
# 1962-08-31   NaN   NaN  NaN  NaN    NaN  37.250   NaN  NaN   NaN   NaN  ...
# 1962-09-30   NaN   NaN  NaN  NaN    NaN  37.250   NaN  NaN   NaN   NaN  ...
# 1962-10-31   NaN   NaN  NaN  NaN    NaN  33.375   NaN  NaN   NaN   NaN  ...
# 1962-11-30   NaN   NaN  NaN  2.5    NaN  39.625   NaN  NaN   NaN   NaN  ...
#
#             VO  FARM  GMCR  JVA  PEET  Excess Return on the Market     SMB  \
# Date
# 1962-07-31 NaN   NaN   NaN  NaN   NaN                       0.0628  0.0163
# 1962-08-31 NaN   NaN   NaN  NaN   NaN                       0.0213  0.0125
# 1962-09-30 NaN   NaN   NaN  NaN   NaN                      -0.0522 -0.0248
# 1962-10-31 NaN   NaN   NaN  NaN   NaN                      -0.0005 -0.0401
# 1962-11-30 NaN   NaN   NaN  NaN   NaN                       0.1087  0.0259
#
#                HML     MOM  USREC
# Date
# 1962-07-31 -0.0357  0.0055      0
# 1962-08-31 -0.0121 -0.0058      0
# 1962-09-30  0.0134  0.0395      0
# 1962-10-31  0.0135  0.0075      0
# 1962-11-30  0.0099 -0.0717      0
#
# [5 rows x 102 columns]

# %% [markdown]
# # Further Data Cleaning

# %% [markdown]
# ## Isolating Sin Stocks Only

# %%
# Removing the NaN value in sin_list
sin_list = sin_list[~pd.isnull(sin_list)]
sin_list
# Out:
# array(['BEAM', 'BEER', 'PFB', 'ABW', 'GBL', 'RUP', 'CNB', 'CKB', 'FAL',
#        'FALB', 'DRE', 'NBW', 'GENBB', 'RG', 'RGLD', 'SLZ', 'SFR', 'KNBWY',
#        'GRRR', 'LONE', 'GHB', 'ABUD', 'BUD', 'ACCOB', 'RKY', 'TAP',
#        'PABT', 'OLYB', 'PTBC', 'HAN', 'BAS', 'SXC', 'CU', 'CCU', 'THT',
#        'HOOK', 'BREW', 'SAM', 'CFN', 'IBCO', 'BRH', 'ABV', 'ABEV', 'AED',
#        'MLB', 'LQU', 'ROX', 'CREG', 'BORN', 'FO', 'MWGP', 'MGPI', 'AFTI',
#        'DR', 'CUE', 'BACA', 'BBRL', 'ADC', 'SH', 'DCS', 'VO', 'HIR',
#        'CHLN', 'CGAS', 'BJD', 'BFD', 'BF', 'CDL', 'DIL', 'GDS', 'SBR',
#        'HBL', 'TFZ', 'TFI', 'HTC', 'JACQ', 'BBR', 'CNWN', 'CDG', 'CDB',
#        'STZ', 'RAIN', 'TBVT', 'TYLR', 'THTR', 'DEO', 'RUM', 'VCO', 'ADSO',
#        'NDC', 'GWT', 'CEDC', 'PTT'], dtype=object)

# %%
sin_stocks = stocks_df[sin_list]
sin_stocks.head()
# Out:
#             BEAM  BEER    PFB  ABW    GBL      RUP    CNB  CKB     FAL  FALB  \
# Date
# 1962-07-31   NaN   NaN  2.625  NaN  1.250  13.2500  8.500  NaN  32.500   NaN
# 1962-08-31   NaN   NaN  2.875  NaN  1.375  13.3125  9.000  NaN  32.250   NaN
# 1962-09-30   NaN   NaN  2.750  NaN  1.125  12.6875  8.500  NaN  30.000   NaN
# 1962-10-31   NaN   NaN  2.375  NaN  0.625  11.6875  9.000  NaN  28.750   NaN
# 1962-11-30   NaN   NaN    NaN  2.5    NaN  11.9375  9.625  NaN  31.125   NaN
#
#             ...  TYLR  THTR  DEO  RUM  VCO  ADSO  NDC  GWT  CEDC  PTT
# Date        ...
# 1962-07-31  ...   NaN   NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN
# 1962-08-31  ...   NaN   NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN
# 1962-09-30  ...   NaN   NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN
# 1962-10-31  ...   NaN   NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN
# 1962-11-30  ...   NaN   NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 93 columns]

# %% [markdown]
# ## Finding Percentage Change in Stocks

# %%
returns_df = sin_stocks.pct_change(limit = None, fill_method = None)
returns_df
# Out:
#             BEAM  BEER       PFB  ABW       GBL       RUP       CNB  CKB  \
# Date
# 1962-07-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 1962-08-31   NaN   NaN  0.095238  NaN  0.100000  0.004717  0.058824  NaN
# 1962-09-30   NaN   NaN -0.043478  NaN -0.181818 -0.046948 -0.055556  NaN
# 1962-10-31   NaN   NaN -0.136364  NaN -0.444444 -0.078818  0.058824  NaN
# 1962-11-30   NaN   NaN       NaN  NaN       NaN  0.021390  0.069444  NaN
# ...          ...   ...       ...  ...       ...       ...       ...  ...
# 2020-08-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-09-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-10-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-11-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-12-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
#
#                  FAL  FALB  ...  TYLR  THTR       DEO  RUM  VCO  ADSO  NDC  \
# Date                        ...
# 1962-07-31       NaN   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-08-31 -0.007692   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-09-30 -0.069767   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-10-31 -0.041667   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-11-30  0.082609   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# ...              ...   ...  ...   ...   ...       ...  ...  ...   ...  ...
# 2020-08-31       NaN   NaN  ...   NaN   NaN -0.087205  NaN  NaN   NaN  NaN
# 2020-09-30       NaN   NaN  ...   NaN   NaN  0.024256  NaN  NaN   NaN  NaN
# 2020-10-31       NaN   NaN  ...   NaN   NaN -0.054337  NaN  NaN   NaN  NaN
# 2020-11-30       NaN   NaN  ...   NaN   NaN  0.190275  NaN  NaN   NaN  NaN
# 2020-12-31       NaN   NaN  ...   NaN   NaN  0.024911  NaN  NaN   NaN  NaN
#
#             GWT  CEDC  PTT
# Date
# 1962-07-31  NaN   NaN  NaN
# 1962-08-31  NaN   NaN  NaN
# 1962-09-30  NaN   NaN  NaN
# 1962-10-31  NaN   NaN  NaN
# 1962-11-30  NaN   NaN  NaN
# ...         ...   ...  ...
# 2020-08-31  NaN   NaN  NaN
# 2020-09-30  NaN   NaN  NaN
# 2020-10-31  NaN   NaN  NaN
# 2020-11-30  NaN   NaN  NaN
# 2020-12-31  NaN   NaN  NaN
#
# [702 rows x 93 columns]

# %% [markdown]
# Using this set of arguments allows for the pct change values to be properly reflected when the stock exits the universe

# %% [markdown]
# ### Removing null values
# - Only the first row is empty, since we found percentage changes for each adjacent row

# %%
returns_df.dropna(how = "all", inplace=True)
returns_df
# Out:
#             BEAM  BEER       PFB  ABW       GBL       RUP       CNB  CKB  \
# Date
# 1962-08-31   NaN   NaN  0.095238  NaN  0.100000  0.004717  0.058824  NaN
# 1962-09-30   NaN   NaN -0.043478  NaN -0.181818 -0.046948 -0.055556  NaN
# 1962-10-31   NaN   NaN -0.136364  NaN -0.444444 -0.078818  0.058824  NaN
# 1962-11-30   NaN   NaN       NaN  NaN       NaN  0.021390  0.069444  NaN
# 1962-12-31   NaN   NaN       NaN  0.0       NaN  0.015707  0.038961  NaN
# ...          ...   ...       ...  ...       ...       ...       ...  ...
# 2020-08-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-09-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-10-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-11-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-12-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
#
#                  FAL  FALB  ...  TYLR  THTR       DEO  RUM  VCO  ADSO  NDC  \
# Date                        ...
# 1962-08-31 -0.007692   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-09-30 -0.069767   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-10-31 -0.041667   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-11-30  0.082609   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# 1962-12-31 -0.028112   NaN  ...   NaN   NaN       NaN  NaN  NaN   NaN  NaN
# ...              ...   ...  ...   ...   ...       ...  ...  ...   ...  ...
# 2020-08-31       NaN   NaN  ...   NaN   NaN -0.087205  NaN  NaN   NaN  NaN
# 2020-09-30       NaN   NaN  ...   NaN   NaN  0.024256  NaN  NaN   NaN  NaN
# 2020-10-31       NaN   NaN  ...   NaN   NaN -0.054337  NaN  NaN   NaN  NaN
# 2020-11-30       NaN   NaN  ...   NaN   NaN  0.190275  NaN  NaN   NaN  NaN
# 2020-12-31       NaN   NaN  ...   NaN   NaN  0.024911  NaN  NaN   NaN  NaN
#
#             GWT  CEDC  PTT
# Date
# 1962-08-31  NaN   NaN  NaN
# 1962-09-30  NaN   NaN  NaN
# 1962-10-31  NaN   NaN  NaN
# 1962-11-30  NaN   NaN  NaN
# 1962-12-31  NaN   NaN  NaN
# ...         ...   ...  ...
# 2020-08-31  NaN   NaN  NaN
# 2020-09-30  NaN   NaN  NaN
# 2020-10-31  NaN   NaN  NaN
# 2020-11-30  NaN   NaN  NaN
# 2020-12-31  NaN   NaN  NaN
#
# [701 rows x 93 columns]

# %% [markdown]
# ## Calculating Individual Weights

# %%
total_no_sin = len(returns_df.columns)
total_no_sin
# Out:
# 93

# %% [markdown]
# ### Calculating Number of Active Stocks for Each Date
# - Deducting number of NaN values per row from the total number of sin stocks to derive the number of active sin stocks for a given date

# %%
returns_df["Num_Active_Stocks"] = total_no_sin - returns_df.isnull().sum(axis = 1)
returns_df["Portfolio_Proportion"] = 1 / returns_df["Num_Active_Stocks"]
returns_df
# Out:
#             BEAM  BEER       PFB  ABW       GBL       RUP       CNB  CKB  \
# Date
# 1962-08-31   NaN   NaN  0.095238  NaN  0.100000  0.004717  0.058824  NaN
# 1962-09-30   NaN   NaN -0.043478  NaN -0.181818 -0.046948 -0.055556  NaN
# 1962-10-31   NaN   NaN -0.136364  NaN -0.444444 -0.078818  0.058824  NaN
# 1962-11-30   NaN   NaN       NaN  NaN       NaN  0.021390  0.069444  NaN
# 1962-12-31   NaN   NaN       NaN  0.0       NaN  0.015707  0.038961  NaN
# ...          ...   ...       ...  ...       ...       ...       ...  ...
# 2020-08-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-09-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-10-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-11-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-12-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
#
#                  FAL  FALB  ...       DEO  RUM  VCO  ADSO  NDC  GWT  CEDC  \
# Date                        ...
# 1962-08-31 -0.007692   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-09-30 -0.069767   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-10-31 -0.041667   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-11-30  0.082609   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-12-31 -0.028112   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# ...              ...   ...  ...       ...  ...  ...   ...  ...  ...   ...
# 2020-08-31       NaN   NaN  ... -0.087205  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-09-30       NaN   NaN  ...  0.024256  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-10-31       NaN   NaN  ... -0.054337  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-11-30       NaN   NaN  ...  0.190275  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-12-31       NaN   NaN  ...  0.024911  NaN  NaN   NaN  NaN  NaN   NaN
#
#             PTT  Num_Active_Stocks  Portfolio_Proportion
# Date
# 1962-08-31  NaN                 19              0.052632
# 1962-09-30  NaN                 19              0.052632
# 1962-10-31  NaN                 19              0.052632
# 1962-11-30  NaN                 17              0.058824
# 1962-12-31  NaN                 18              0.055556
# ...         ...                ...                   ...
# 2020-08-31  NaN                 11              0.090909
# 2020-09-30  NaN                 10              0.100000
# 2020-10-31  NaN                 10              0.100000
# 2020-11-30  NaN                 10              0.100000
# 2020-12-31  NaN                 10              0.100000
#
# [701 rows x 95 columns]

# %% [markdown]
# ## Multiplying percentage returns by 1/N stocks (Portfolio_Proportion)

# %%
portfolio_returns = returns_df.mul(returns_df["Portfolio_Proportion"], axis = 0)
portfolio_returns.drop(columns = ["Num_Active_Stocks", "Portfolio_Proportion"], inplace = True)

# %% [markdown]
# ## Finding Row Wise Sum of Portfolio Percentage Returns

# %%
portfolio_returns["Portfolio_Returns"] = portfolio_returns.sum(axis = 1)

# %%
portfolio_returns["Portfolio_Proportion"] = returns_df["Portfolio_Proportion"]
portfolio_returns
# Out:
#             BEAM  BEER       PFB  ABW       GBL       RUP       CNB  CKB  \
# Date
# 1962-08-31   NaN   NaN  0.005013  NaN  0.005263  0.000248  0.003096  NaN
# 1962-09-30   NaN   NaN -0.002288  NaN -0.009569 -0.002471 -0.002924  NaN
# 1962-10-31   NaN   NaN -0.007177  NaN -0.023392 -0.004148  0.003096  NaN
# 1962-11-30   NaN   NaN       NaN  NaN       NaN  0.001258  0.004085  NaN
# 1962-12-31   NaN   NaN       NaN  0.0       NaN  0.000873  0.002165  NaN
# ...          ...   ...       ...  ...       ...       ...       ...  ...
# 2020-08-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-09-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-10-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-11-30   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
# 2020-12-31   NaN   NaN       NaN  NaN       NaN       NaN       NaN  NaN
#
#                  FAL  FALB  ...       DEO  RUM  VCO  ADSO  NDC  GWT  CEDC  \
# Date                        ...
# 1962-08-31 -0.000405   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-09-30 -0.003672   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-10-31 -0.002193   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-11-30  0.004859   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1962-12-31 -0.001562   NaN  ...       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# ...              ...   ...  ...       ...  ...  ...   ...  ...  ...   ...
# 2020-08-31       NaN   NaN  ... -0.007928  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-09-30       NaN   NaN  ...  0.002426  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-10-31       NaN   NaN  ... -0.005434  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-11-30       NaN   NaN  ...  0.019028  NaN  NaN   NaN  NaN  NaN   NaN
# 2020-12-31       NaN   NaN  ...  0.002491  NaN  NaN   NaN  NaN  NaN   NaN
#
#             PTT  Portfolio_Returns  Portfolio_Proportion
# Date
# 1962-08-31  NaN          -0.028063              0.052632
# 1962-09-30  NaN           7.390793              0.052632
# 1962-10-31  NaN          -0.095336              0.052632
# 1962-11-30  NaN           0.044245              0.058824
# 1962-12-31  NaN           2.401140              0.055556
# ...         ...                ...                   ...
# 2020-08-31  NaN          -0.132603              0.090909
# 2020-09-30  NaN           9.329493              0.100000
# 2020-10-31  NaN          -0.116476              0.100000
# 2020-11-30  NaN           0.277553              0.100000
# 2020-12-31  NaN         134.027247              0.100000
#
# [701 rows x 95 columns]

# %%
portfolio_merged = pd.concat([returns_df[["Num_Active_Stocks"]], portfolio_returns], axis = 1, join = "inner")

# %%
portfolio_merged
# Out:
#             Num_Active_Stocks  BEAM  BEER       PFB  ABW       GBL       RUP  \
# Date
# 1962-08-31                 19   NaN   NaN  0.005013  NaN  0.005263  0.000248
# 1962-09-30                 19   NaN   NaN -0.002288  NaN -0.009569 -0.002471
# 1962-10-31                 19   NaN   NaN -0.007177  NaN -0.023392 -0.004148
# 1962-11-30                 17   NaN   NaN       NaN  NaN       NaN  0.001258
# 1962-12-31                 18   NaN   NaN       NaN  0.0       NaN  0.000873
# ...                       ...   ...   ...       ...  ...       ...       ...
# 2020-08-31                 11   NaN   NaN       NaN  NaN       NaN       NaN
# 2020-09-30                 10   NaN   NaN       NaN  NaN       NaN       NaN
# 2020-10-31                 10   NaN   NaN       NaN  NaN       NaN       NaN
# 2020-11-30                 10   NaN   NaN       NaN  NaN       NaN       NaN
# 2020-12-31                 10   NaN   NaN       NaN  NaN       NaN       NaN
#
#                  CNB  CKB       FAL  ...       DEO  RUM  VCO  ADSO  NDC  GWT  \
# Date                                 ...
# 1962-08-31  0.003096  NaN -0.000405  ...       NaN  NaN  NaN   NaN  NaN  NaN
# 1962-09-30 -0.002924  NaN -0.003672  ...       NaN  NaN  NaN   NaN  NaN  NaN
# 1962-10-31  0.003096  NaN -0.002193  ...       NaN  NaN  NaN   NaN  NaN  NaN
# 1962-11-30  0.004085  NaN  0.004859  ...       NaN  NaN  NaN   NaN  NaN  NaN
# 1962-12-31  0.002165  NaN -0.001562  ...       NaN  NaN  NaN   NaN  NaN  NaN
# ...              ...  ...       ...  ...       ...  ...  ...   ...  ...  ...
# 2020-08-31       NaN  NaN       NaN  ... -0.007928  NaN  NaN   NaN  NaN  NaN
# 2020-09-30       NaN  NaN       NaN  ...  0.002426  NaN  NaN   NaN  NaN  NaN
# 2020-10-31       NaN  NaN       NaN  ... -0.005434  NaN  NaN   NaN  NaN  NaN
# 2020-11-30       NaN  NaN       NaN  ...  0.019028  NaN  NaN   NaN  NaN  NaN
# 2020-12-31       NaN  NaN       NaN  ...  0.002491  NaN  NaN   NaN  NaN  NaN
#
#             CEDC  PTT  Portfolio_Returns  Portfolio_Proportion
# Date
# 1962-08-31   NaN  NaN          -0.028063              0.052632
# 1962-09-30   NaN  NaN           7.390793              0.052632
# 1962-10-31   NaN  NaN          -0.095336              0.052632
# 1962-11-30   NaN  NaN           0.044245              0.058824
# 1962-12-31   NaN  NaN           2.401140              0.055556
# ...          ...  ...                ...                   ...
# 2020-08-31   NaN  NaN          -0.132603              0.090909
# 2020-09-30   NaN  NaN           9.329493              0.100000
# 2020-10-31   NaN  NaN          -0.116476              0.100000
# 2020-11-30   NaN  NaN           0.277553              0.100000
# 2020-12-31   NaN  NaN         134.027247              0.100000
#
# [701 rows x 96 columns]

# %%
portfolio_merged.to_csv("sin_portfolio_returns.csv")
